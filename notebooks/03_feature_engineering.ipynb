# %% [markdown]
# ### feature_engineering.ipynb

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('../data/processed/final_dataset.csv')

# %%
df.columns = df.columns.str.strip().str.lower()
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values('date')

# %%
df.head()
# Out:
#         date    cpi    wpi
# 0 2012-04-01   97.8  104.7
# 1 2012-05-01   98.6  105.3
# 2 2012-06-01   99.8  105.3
# 3 2012-07-01  101.1  106.2
# 4 2012-08-01  102.2  106.9

# %% [markdown]
# #### Time Features

# %%
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year 
df['quarter'] = df['date'].dt.quarter

df[['date','month','year','quarter']].head()
# Out:
#         date  month  year  quarter
# 0 2012-04-01      4  2012        2
# 1 2012-05-01      5  2012        2
# 2 2012-06-01      6  2012        2
# 3 2012-07-01      7  2012        3
# 4 2012-08-01      8  2012        3

# %% [markdown]
# #### Lag Features

# %%
df['lag_1'] = df['cpi'].shift(1)
df['lag_2'] = df['cpi'].shift(2)
df['lag_3'] = df['cpi'].shift(3)
df['lag_6'] = df['cpi'].shift(6)
df['lag_12'] = df['cpi'].shift(12)

df[['cpi','lag_1','lag_2']].head(10)
# Out:
#      cpi  lag_1  lag_2
# 0   97.8    NaN    NaN
# 1   98.6   97.8    NaN
# 2   99.8   98.6   97.8
# 3  101.1   99.8   98.6
# 4  102.2  101.1   99.8
# 5  102.9  102.2  101.1
# 6  103.6  102.9  102.2
# 7  104.3  103.6  102.9
# 8  104.6  104.3  103.6
# 9  104.6  104.6  104.3

# %% [markdown]
# #### Rolling Features

# %%
df['rolling_mean_3'] = df['cpi'].rolling(3).mean()
df['rolling_std_3'] = df['cpi'].rolling(3).std()

df['rolling_mean_6'] = df['cpi'].rolling(6).mean()
df['rolling_std_6'] = df['cpi'].rolling(6).std()

# %% [markdown]
# #### Growth (Inflation %)

# %%
df['cpi_pct_change'] = df['cpi'].pct_change() * 100

df[['cpi','cpi_pct_change']].head()
# Out:
#      cpi  cpi_pct_change
# 0   97.8             NaN
# 1   98.6        0.817996
# 2   99.8        1.217039
# 3  101.1        1.302605
# 4  102.2        1.088032

# %% [markdown]
# #### Difference Feature

# %%
df['cpi_diff'] = df['cpi'].diff()
df['cpi_diff'].head()
# Out:
# 0    NaN
# 1    0.8
# 2    1.2
# 3    1.3
# 4    1.1
# Name: cpi_diff, dtype: float64

# %% [markdown]
# ## WPI Features

# %%
df['wpi_pct_change'] = df['wpi'].pct_change() * 100
df['wpi_lag1'] = df['wpi'].shift(1)

# %%
df['trend_index'] = range(len(df))
df['cpi_wpi_diff'] = df['cpi'] - df['wpi']

# %%
df = df.dropna()

df.shape
# Out:
# (152, 21)

# %%
df.head()
# Out:
#          date    cpi    wpi  month  year  quarter  lag_1  lag_2  lag_3  lag_6  \
# 13 2013-05-01  106.9  108.6      5  2013        2  106.1  105.5  105.3  104.3
# 14 2013-06-01  109.3  110.1      6  2013        2  106.9  106.1  105.5  104.6
# 15 2013-07-01  111.0  111.2      7  2013        3  109.3  106.9  106.1  104.6
# 16 2013-08-01  112.4  112.9      8  2013        3  111.0  109.3  106.9  105.3
# 17 2013-09-01  113.7  114.3      9  2013        3  112.4  111.0  109.3  105.5
#
#     ...  rolling_mean_3  rolling_std_3  rolling_mean_6  rolling_std_6  \
# 13  ...      106.166667       0.702377      105.500000       0.892188
# 14  ...      107.433333       1.665333      106.283333       1.669032
# 15  ...      109.066667       2.059935      107.350000       2.302824
# 16  ...      110.900000       1.552417      108.533333       2.807609
# 17  ...      112.366667       1.350309      109.900000       3.023243
#
#     cpi_pct_change  cpi_diff  wpi_pct_change  wpi_lag1  trend_index  \
# 13        0.754006       0.8        0.000000     108.6            1
# 14        2.245089       2.4        1.381215     108.6            2
# 15        1.555352       1.7        0.999092     110.1            3
# 16        1.261261       1.4        1.528777     111.2            4
# 17        1.156584       1.3        1.240035     112.9            5
#
#     cpi_wpi_diff
# 13          -1.7
# 14          -0.8
# 15          -0.2
# 16          -0.5
# 17          -0.6
#
# [5 rows x 21 columns]

# %%
df.to_csv('../data/processed/final_features.csv', index=False)
